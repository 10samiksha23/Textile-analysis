# %% [markdown]
# # **Texttile Analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\Samiksha\Downloads\WICVOCDataAll_030223.csv\WICVOCDataAll_030223.csv")
# Out:
# C:\Users\Samiksha\AppData\Local\Temp\ipykernel_16412\598161780.py:3: DtypeWarning: Columns (4,25,26,45,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\Samiksha\Downloads\WICVOCDataAll_030223.csv\WICVOCDataAll_030223.csv")

# %% [markdown]
# # **Basic opertation**

# %%
df.head()
# Out:
#    exchange_nr                       source company means_of_exchange  \
# 0          1.0  WIC_1.05.01.02_1301_136-138     WIC           Leusden
# 1          2.0  WIC_1.05.01.02_1301_136-138     WIC           Leusden
# 2          3.0  WIC_1.05.01.02_1303_214-216     WIC        Beekestijn
# 3          4.0  WIC_1.05.01.02_1302_225-227     WIC         Sem Galey
# 4          5.0  WIC_1.05.01.02_1302_225-227     WIC         Sem Galey
#
#      ship_captain orig_date_src  orig_yr   orig_date orig_exact_date_yn  \
# 0     Jacob Thijl           scs   1719.0  1719-12-26                  y
# 1     Jacob Thijl           scs   1719.0  1719-12-26                  y
# 2  Dirck de Wolff          arch   1721.0  1721-02-19                  y
# 3     Jan Andries           scs   1721.0   1721-2-19                  y
# 4     Jan Andries           scs   1721.0   1721-2-19                  y
#
#   orig_loc_port_arch  ... total_value_other ps_value_gulden ps_value_stuivers  \
# ...

# %%
# Get basic info about dataset
df.info()

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22878 entries, 0 to 22877
# Data columns (total 57 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   exchange_nr                                                                                       22877 non-null  float64
#  1   source                                                                                            22877 non-null  object
#  2   company                                                                                           22877 non-null  object
#  3   means_of_exchange                                                                                 22877 non-null  object
# ...

# %% [markdown]
# # **Check unique values**

# %%
# Check for missing values
df.isnull().sum()
# Out:
# exchange_nr                                                                                             1
# source                                                                                                  1
# company                                                                                                 1
# means_of_exchange                                                                                       1
# ship_captain                                                                                        20879
# orig_date_src                                                                                           1
# orig_yr                                                                                                 1
# orig_date                                                                                             649
# orig_exact_date_yn                                                                                   1464
# ...

# %% [markdown]
# # **Statstical Presentation**

# %%
# Statistical summary
df.describe()
# Out:
#         exchange_nr       orig_yr       dest_yr  textile_subcategory  \
# count  2.287700e+04  22877.000000  22308.000000                  4.0
# mean   1.906304e+06   1714.785549   1715.199121                 14.0
# std    3.569299e+05      5.959801      5.959508                  0.0
# min    1.000000e+00   1700.000000   1701.000000                 14.0
# 25%    2.004106e+06   1710.000000   1711.000000                 14.0
# 50%    2.009844e+06   1713.000000   1713.000000                 14.0
# 75%    2.015568e+06   1722.000000   1722.000000                 14.0
# max    2.021291e+06   1724.000000   1735.000000                 14.0
#
#        textile_quality_inferred  total_value_other  ps_value_gulden  \
# count                       0.0                0.0      1291.000000
# mean                        NaN                NaN         8.442752
# std                         NaN                NaN         7.008154
# min                         NaN                NaN         0.000000
# ...

# %% [markdown]
# # **Unique values**

# %%
# Display column names
df.columns

# For categorical columns, check unique values
for col in df.select_dtypes(include='object').columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# source: 1521 unique values
# company: 2 unique values
# means_of_exchange: 638 unique values
# ship_captain: 106 unique values
# orig_date_src: 6 unique values
# orig_date: 779 unique values
# orig_exact_date_yn: 2 unique values
# orig_loc_port_arch: 52 unique values
# orig_loc_region_arch: 34 unique values
# orig_loc_port_modern: 44 unique values
# orig_loc_region_modern: 18 unique values
# orig_loc_abr: 18 unique values
# dest_date_src: 6 unique values
# dest_date: 794 unique values
# dest_exact_date_yn: 2 unique values
# dest_loc_port_arch: 55 unique values
# dest_loc_region_arch: 46 unique values
# dest_loc_port: 48 unique values
# dest_loc_region: 23 unique values
# dest_loc_abr: 24 unique values
# textile_quantity: 2169 unique values
# textile_unit: 39 unique values
# els_per_ps: 210 unique values
# supplier: 427 unique values
# textile_category: 6 unique values
# textile_name: 257 unique values
# textile_modifier_fulltext: 2019 unique values
# ...

# %% [markdown]
# # **Drop duplictates**

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)

# Fill or drop missing values if necessary
# df.fillna(method='ffill', inplace=True)

# %%
df
# Out:
#        exchange_nr                       source company  \
# 0              1.0  WIC_1.05.01.02_1301_136-138     WIC
# 1              2.0  WIC_1.05.01.02_1301_136-138     WIC
# 2              3.0  WIC_1.05.01.02_1303_214-216     WIC
# 3              4.0  WIC_1.05.01.02_1302_225-227     WIC
# 4              5.0  WIC_1.05.01.02_1302_225-227     WIC
# ...            ...                          ...     ...
# 22873    2021288.0                    src_00086     VOC
# 22874    2021289.0                    src_00086     VOC
# 22875    2021290.0                    src_00086     VOC
# 22876    2021291.0                    src_00086     VOC
# 22877          NaN                          NaN     NaN
#
#                                        means_of_exchange    ship_captain  \
# 0                                                Leusden     Jacob Thijl
# 1                                                Leusden     Jacob Thijl
# ...

# %% [markdown]
# # **Histogram**

# %%
# Histogram for numeric columns
df.hist(figsize=(15, 10), bins=20)
plt.tight_layout()
plt.show()

# Count plot for a categorical column (replace 'CategoryCol' with actual column)
# sns.countplot(data=df, x='CategoryCol')

# %% [markdown]
# # **Group by**

# %%
# Group by and aggregation (example)
df.groupby('means_of_exchange')['ps_value_stuivers'].mean()
# Out:
# means_of_exchange
# 't Ghijn, Donau, Rijssel   NaN
# 1 sloep, diverse           NaN
# 1 sloep, verscheidene      NaN
# 1 vaartuig, diverse        NaN
# Abbekerk                   NaN
#                             ..
# sloep, verschiedene        NaN
# t Ghijn                    NaN
# t Ghijn, Horstendaal       NaN
# vaartuig, diverse          NaN
# various ships              NaN
# Name: ps_value_stuivers, Length: 638, dtype: float64

# %%
df['company'].nunique()
# Out:
# 2

# %% [markdown]
# # **line Graph**

# %%
import matplotlib.pyplot as plt

pd.pivot_table(
    df,
    index="source",
    values="ps_value_stuivers",
    aggfunc="mean"
).plot(kind="line")

plt.xticks(rotation=45)  # Rotate x-axis tick labels by 45 degrees
plt.tight_layout()       # Adjust layout to prevent label cutoff
plt.show()

# %% [markdown]
# # **pie chart**

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Belvliet','Sem Galey','Leusden','Beekestijn']
sizes = [40, 25, 20, 15]  # Values for each label
colors = ['gold', 'lightblue', 'lightcoral', 'green']
explode = (0.1, 0, 0, 0)  # "explode" the first slice

# Create pie chart
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%',
        startangle=140, explode=explode, shadow=True)

plt.title('Sales Distribution of Products')
plt.axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle
plt.show()

# %% [markdown]
# # **Distribution**

# %%
df['ps_value_stuivers'].describe()

# Histogram
df['ps_value_stuivers'].hist(bins=30)
plt.title('Distribution')
plt.show()

# %% [markdown]
# # **Scatter Plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Between Numerical Variables')
plt.show()

# Scatter plot
sns.scatterplot(data=df, x='ps_value_stuivers', y='ps_value_penningen')
plt.title('Scatter Plot')
plt.show()

# %%
sns.boxplot(data=df, x='source', y='ps_value_stuivers')
# Out:
# <Axes: xlabel='source', ylabel='ps_value_stuivers'>

# %% [markdown]
# # **pivot table**

# %%
# Pivot to compare multiple dimensions
pd.pivot_table(df, index ='means_of_exchange', values='ps_value_stuivers', aggfunc='mean')
# Out:
#                      ps_value_stuivers
# means_of_exchange
# Abrahams Offerhande          14.208333
# Accra                        31.562500
# Acredam                      18.735887
# Adrichem                    842.200893
# Africa                        3.142857
# ...                                ...
# Vlissingen                    2.944444
# Vrijehijdt                   27.500000
# Vrijhijt                     10.000000
# Vrindschap                   40.857143
# Waartwijk                    18.500000
#
# [82 rows x 1 columns]

# %%
df[df.eq('Leusden').any(axis=1)]
# Out:
#      exchange_nr                       source company means_of_exchange  \
# 0            1.0  WIC_1.05.01.02_1301_136-138     WIC           Leusden
# 1            2.0  WIC_1.05.01.02_1301_136-138     WIC           Leusden
# 9           10.0  WIC_1.05.01.02_1303_249-250     WIC           Leusden
# 26          27.0  WIC_1.05.01.02_1303_249-250     WIC           Leusden
# 27          28.0  WIC_1.05.01.02_1303_249-250     WIC           Leusden
# ..           ...                          ...     ...               ...
# 593    1000231.0  WIC_1.05.01.02_1304_377-378     WIC           Leusden
# 594    1000232.0  WIC_1.05.01.02_1304_377-378     WIC           Leusden
# 595    1000233.0  WIC_1.05.01.02_1304_377-378     WIC           Leusden
# 596    1000234.0  WIC_1.05.01.02_1304_377-378     WIC           Leusden
# 597    1000235.0  WIC_1.05.01.02_1304_377-378     WIC           Leusden
#
#     ship_captain orig_date_src  orig_yr   orig_date orig_exact_date_yn  \
# ...
